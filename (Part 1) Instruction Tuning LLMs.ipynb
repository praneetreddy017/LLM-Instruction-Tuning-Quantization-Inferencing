# %% [markdown]
# ### Instruction Tuning an LLM (Flan-T5) on custom data for Q&A purposes
# ### This is Part 1 of two planned parts wherein the first notebook deals with tuning the LLM whereas the second notebook deals with quantization and running inferences

# %% [markdown]
# Every organization these days is rushing to develop their own LLM. If that is not an option for you but you want to leverage LLMs capabilities for tasks such as Q&A, you are in the right place. In this notebook we will explore instruction tuning an LLM over our own data. More specifically, we will be leveraging the Q&A capabilities of LLMs to classify sentences based on a set of instructions the user provides.
#
# But before we dive deeper, we need to understand what Instruction Tuning is all about. To put it briefly, Instruction Tuning is the method of training the model over to perform an NLP task in a certain way by structuring the data in the form of instructions.
#
# For Example:<br>
# **Instruction: Read the Context below and answer the Question based by picking from the Choices provided below<br>
# Context: The Clinician said, "His brother is homeless"<br>
# Question: "In the clinician\'s opinon, was the person themself homeless?""<br>
# Choices: Yes; No<br>
# Answer:** **<font color=red>No</font>**
#
# The text highlighted in **bold** will constitute the data portion and the text highlighted in **<font color=red>red</font>** is what was commonly refer to as label in traditional Machine. So that's about what we need to know about the data.
#
# For more information regarding the format of the prompt/context, please read this research paper: **Context-faithful Prompting for Large Language Models**: https://arxiv.org/pdf/2303.11315.pdf
#
# You may be wondering that it would be computationally expensive to train an LLM. While that is true, we can circuvent this issue with the help of what is referred to as Parameter Effecient Fine-Tuning (PEFT). Using PEFT, we only need to train a portion of the model weights and not the entire model itself.

# %% [markdown]
# Here is a list of the main packages used:
# 1. adapter-transformers (can import using "import transformers". Do not need "transformers" installed as this is an extension over the transformers library)
# 2. torch
# 3. datasets
# 4. tqdm
# 5. pandas
# 6. re
# 7. gc

# %% [markdown]
# We are importing the Garbage Collector Package and invoking it manually just to be sure that cache is being cleared

# %%
import gc
gc.collect()
# Out:
# 254

# %% [markdown]
# My data is in a text file but if your data is not in a text file and is in CSV file, please skip the next two cells<br>

# %%
import re # used to extract entities from each sentence 
# Using readlines()
data_file = open('real_homeless_data_v1.3.txt', 'r')
Lines = data_file.readlines()

# %% [markdown]
# The data in my text file is in the same format as the example showcased at the beginning of this notebook. Using a regular expression that works for my data, I am extracting each sentence and storing it in a unqiue variable corresponding to each sentence. I then append all of them as elements of a lists into a list itself (list of lists). Please print the below data if you would like to better understand what the data looks like.

# %%
csv_list = []  
for line in range(0, len(Lines),6):
    print(Lines[line] + Lines[line + 1] + Lines[line + 2] + Lines[line + 3] + Lines[line + 4])
    
#     break
    
    txt = Lines[line]
    i = re.findall("^Instruction: .*?Choices.", txt)
    print(i)
    
    txt = Lines[line + 1]
    c = re.findall("^Context: (The Clinician said, \".*\")", txt)
    print(c)
    
    txt = Lines[line + 2] 
    q = re.findall("^Question: (.*\?\")", txt)
    print(q)
    
    txt = Lines[line + 3] 
    ch = re.findall("^Choices: (.*No)", txt)
    print(ch)
    
    txt = Lines[line + 4]
    a = re.findall("^Answer: (.*)\.", txt)
    print(a)
    
    csv_list.append([i[0], c[0], q[0], ch[0], a[0]])
#     print(csv_list)
    
    
#     break
# Out:
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Social History: Pt is homeless."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Social History: Pt is homeless."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Social History: He is homeless, and stays in a shelter."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Social History: He is homeless, and stays in a shelter."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "He is homeless and currently staying with friends."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "He is homeless and currently staying with friends."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "The patient is currently homeless, staying with friends, moved from   to   in  , homosexual."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "The patient is currently homeless, staying with friends, moved from   to   in  , homosexual."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "previously from  , moved to the states after high school; lives in   and works as a social worker with the homeless denies tobacco or IVDU drinks ETOH occasionally   "
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: No.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "previously from  , moved to the states after high school; lives in   and works as a social worker with the homeless denies tobacco or IVDU drinks ETOH occasionally   "']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['No']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "The patient was born in  ,  . Previously homeless, currently resides in   Manor."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "The patient was born in  ,  . Previously homeless, currently resides in   Manor."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, " Mr.   is homeless and lives at   House in   for now."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, " Mr.   is homeless and lives at   House in   for now."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Social History: homeless;   quarts vodka/day;   ppd tobacco; no recent ivdu, but used cocaine and heroin in the past; smokes MJ"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Social History: homeless;   quarts vodka/day;   ppd tobacco; no recent ivdu, but used cocaine and heroin in the past; smokes MJ"']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "He is now homeless and was taking the train to   when he decided to have a 40oz beer."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "He is now homeless and was taking the train to   when he decided to have a 40oz beer."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Currently homeless, but formerly living with an uncle in  . Previous alcohol abuser, but sober for 2 years until today."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Currently homeless, but formerly living with an uncle in  . Previous alcohol abuser, but sober for 2 years until today."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "The patient was supposed to be discharged on  .  However, it was discovered that Mr.   was homeless after his brother kicked him out of the house and he had no place to go."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "The patient was supposed to be discharged on  .  However, it was discovered that Mr.   was homeless after his brother kicked him out of the house and he had no place to go."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Pt has been living on the street for 3-4 months."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Pt has been living on the street for 3-4 months."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, " MEDICATIONS:  Denies any current home medications."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: No.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, " MEDICATIONS:  Denies any current home medications."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['No']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, ""Has lost job at homeless shelter   EtOH abuse.""
# Question: ""In the clinician's opinon, was the person themself homeless?""
# Choices: Yes; No
# Answer: No.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, ""Has lost job at homeless shelter   EtOH abuse.""']
# ['""In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['No']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "In the past, patient stated to some providers he had a home in   and to others that he was homeless."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "In the past, patient stated to some providers he had a home in   and to others that he was homeless."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Social History: Unable to obtain, reports of homelessness."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Social History: Unable to obtain, reports of homelessness."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "SOCIAL HISTORY:  The patient lives in a residence for elderly, homeless women.  The patient has a good resident contact,       who knows the patient very well."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "SOCIAL HISTORY:  The patient lives in a residence for elderly, homeless women.  The patient has a good resident contact,       who knows the patient very well."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Has been living with mother and caring for her. Will be moving back in with boyfriend soon.   hx of homelessness;"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Has been living with mother and caring for her. Will be moving back in with boyfriend soon.   hx of homelessness;"']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "She has a history of homelessness"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "She has a history of homelessness"']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Has been there since ' ?"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: No.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Has been there since \' ?"']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['No']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Social History: Lives alone with several cats, found in filthy apt full of feces."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: No.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Social History: Lives alone with several cats, found in filthy apt full of feces."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['No']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Group home can be reached at  ."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: No.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Group home can be reached at  ."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['No']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, " Chief Complaint:  0 ft."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: No.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, " Chief Complaint:  0 ft."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['No']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Physical Exam: VS: 97.5 149/82 57 20 99/3L (no home O2)"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: No.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Physical Exam: VS: 97.5 149/82 57 20 99/3L (no home O2)"']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['No']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "He has spent time in a homeless shelter x 1 month 3 months ago and was incarcerated last in  ."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "He has spent time in a homeless shelter x 1 month 3 months ago and was incarcerated last in  ."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "evicted yesterday."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "evicted yesterday."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "his brother was homeless"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: No.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "his brother was homeless"']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['No']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, " 5. Follow up:  Complicated social situation with tenuous housing; lives on street as well as with children.  Seen by SW while in house; offered etoh counseling/programs, but patient refused.  He will f/u with Dr.     in   clinic; on discharge, this appointment was set up."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, " 5. Follow up:  Complicated social situation with tenuous housing; lives on street as well as with children.  Seen by SW while in house; offered etoh counseling/programs, but patient refused.  He will f/u with Dr.     in   clinic; on discharge, this appointment was set up."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "We discussed starting anticoagulation, but felt that it was unnecessary and potentially harmful in this patient with a CHADS-2 score of 1 (age), potential medical non-compliance (history of homelessness), and significant fall risk (history of multiple mechanical falls in recent weeks).  We started him on aspirin at a dose of 325 mg once daily."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "We discussed starting anticoagulation, but felt that it was unnecessary and potentially harmful in this patient with a CHADS-2 score of 1 (age), potential medical non-compliance (history of homelessness), and significant fall risk (history of multiple mechanical falls in recent weeks).  We started him on aspirin at a dose of 325 mg once daily."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Past Medical History: Alcohol Abuse Hypertension Pancreatitis Bulimia   Social History: - Tobacco: denies - Alcohol: history of abuse, currently in a detox program at   - Illicits: denies Currently homeless and living out of her car   "
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Past Medical History: Alcohol Abuse Hypertension Pancreatitis Bulimia   Social History: - Tobacco: denies - Alcohol: history of abuse, currently in a detox program at   - Illicits: denies Currently homeless and living out of her car   "']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Has previously stayed in multiple shelters."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "Has previously stayed in multiple shelters."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "SOCIAL HISTORY:  He is apparently homeless.  Alcohol - Unable to quantify."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
#
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, "SOCIAL HISTORY:  He is apparently homeless.  Alcohol - Unable to quantify."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, " Social work was closely involved throughout his hospital stay assisting with issues surrounding being homeless and for substance abuse."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer: Yes.
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.']
# ['The Clinician said, " Social work was closely involved throughout his hospital stay assisting with issues surrounding being homeless and for substance abuse."']
# ['"In the clinician\'s opinon, was the person themself homeless?"']
# ['Yes; No']
# ['Yes']

# %% [markdown]
# Now, I am converting the data from list into a Dataframe and saving it as a CSV. If data is already in a CSV, better to start here. Have a good look at how the data is structured. Each column corresponds to a unqiue entity of the prompt. We have separate columns for Instruction, Context, Question, Choices, and Answer. I am sure there are better ways of storing your data and using them for training but this works for now.

# %%
import pandas as pd

df = pd.DataFrame (csv_list, columns = ['Instruction','Context', 'Question', 'Choices', 'Answer'])


df.to_csv("train_data.csv", sep=',')
df.head(100)
# Out:
#                                           Instruction
# 0   Instruction: Read what the Clinician said in t...  \
# 1   Instruction: Read what the Clinician said in t...
# 2   Instruction: Read what the Clinician said in t...
# 3   Instruction: Read what the Clinician said in t...
# 4   Instruction: Read what the Clinician said in t...
# 5   Instruction: Read what the Clinician said in t...
# 6   Instruction: Read what the Clinician said in t...
# 7   Instruction: Read what the Clinician said in t...
# 8   Instruction: Read what the Clinician said in t...
# 9   Instruction: Read what the Clinician said in t...
# 10  Instruction: Read what the Clinician said in t...
# 11  Instruction: Read what the Clinician said in t...
# 12  Instruction: Read what the Clinician said in t...
# 13  Instruction: Read what the Clinician said in t...
# 14  Instruction: Read what the Clinician said in t...
# 15  Instruction: Read what the Clinician said in t...
# 16  Instruction: Read what the Clinician said in t...
# 17  Instruction: Read what the Clinician said in t...
# 18  Instruction: Read what the Clinician said in t...
# 19  Instruction: Read what the Clinician said in t...
# 20  Instruction: Read what the Clinician said in t...
# 21  Instruction: Read what the Clinician said in t...
# 22  Instruction: Read what the Clinician said in t...
# 23  Instruction: Read what the Clinician said in t...
# 24  Instruction: Read what the Clinician said in t...
# 25  Instruction: Read what the Clinician said in t...
# 26  Instruction: Read what the Clinician said in t...
# 27  Instruction: Read what the Clinician said in t...
# 28  Instruction: Read what the Clinician said in t...
# 29  Instruction: Read what the Clinician said in t...
# 30  Instruction: Read what the Clinician said in t...
# 31  Instruction: Read what the Clinician said in t...
# 32  Instruction: Read what the Clinician said in t...
#
#                                               Context
# 0   The Clinician said, "Social History: Pt is hom...  \
# 1   The Clinician said, "Social History: He is hom...
# 2   The Clinician said, "He is homeless and curren...
# 3   The Clinician said, "The patient is currently ...
# 4   The Clinician said, "previously from  , moved ...
# 5   The Clinician said, "The patient was born in  ...
# 6   The Clinician said, " Mr.   is homeless and li...
# 7   The Clinician said, "Social History: homeless;...
# 8   The Clinician said, "He is now homeless and wa...
# 9   The Clinician said, "Currently homeless, but f...
# 10  The Clinician said, "The patient was supposed ...
# 11  The Clinician said, "Pt has been living on the...
# 12  The Clinician said, " MEDICATIONS:  Denies any...
# 13  The Clinician said, ""Has lost job at homeless...
# 14  The Clinician said, "In the past, patient stat...
# 15  The Clinician said, "Social History: Unable to...
# 16  The Clinician said, "SOCIAL HISTORY:  The pati...
# 17  The Clinician said, "Has been living with moth...
# 18  The Clinician said, "She has a history of home...
# 19     The Clinician said, "Has been there since ' ?"
# 20  The Clinician said, "Social History: Lives alo...
# 21  The Clinician said, "Group home can be reached...
# 22     The Clinician said, " Chief Complaint:  0 ft."
# 23  The Clinician said, "Physical Exam: VS: 97.5 1...
# 24  The Clinician said, "He has spent time in a ho...
# 25           The Clinician said, "evicted yesterday."
# 26     The Clinician said, "his brother was homeless"
# 27  The Clinician said, " 5. Follow up:  Complicat...
# 28  The Clinician said, "We discussed starting ant...
# 29  The Clinician said, "Past Medical History: Alc...
# 30  The Clinician said, "Has previously stayed in ...
# 31  The Clinician said, "SOCIAL HISTORY:  He is ap...
# 32  The Clinician said, " Social work was closely ...
#
#                                              Question  Choices Answer
# 0   "In the clinician's opinon, was the person the...  Yes; No    Yes
# 1   "In the clinician's opinon, was the person the...  Yes; No    Yes
# 2   "In the clinician's opinon, was the person the...  Yes; No    Yes
# 3   "In the clinician's opinon, was the person the...  Yes; No    Yes
# 4   "In the clinician's opinon, was the person the...  Yes; No     No
# 5   "In the clinician's opinon, was the person the...  Yes; No    Yes
# 6   "In the clinician's opinon, was the person the...  Yes; No    Yes
# 7   "In the clinician's opinon, was the person the...  Yes; No    Yes
# 8   "In the clinician's opinon, was the person the...  Yes; No    Yes
# 9   "In the clinician's opinon, was the person the...  Yes; No    Yes
# 10  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 11  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 12  "In the clinician's opinon, was the person the...  Yes; No     No
# 13  ""In the clinician's opinon, was the person th...  Yes; No     No
# 14  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 15  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 16  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 17  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 18  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 19  "In the clinician's opinon, was the person the...  Yes; No     No
# 20  "In the clinician's opinon, was the person the...  Yes; No     No
# 21  "In the clinician's opinon, was the person the...  Yes; No     No
# 22  "In the clinician's opinon, was the person the...  Yes; No     No
# 23  "In the clinician's opinon, was the person the...  Yes; No     No
# 24  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 25  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 26  "In the clinician's opinon, was the person the...  Yes; No     No
# 27  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 28  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 29  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 30  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 31  "In the clinician's opinon, was the person the...  Yes; No    Yes
# 32  "In the clinician's opinon, was the person the...  Yes; No    Yes

# %% [markdown]
# Removing duplicates in the dataframe based on the Context column

# %%
df = df.drop_duplicates(subset = "Context")

# %% [markdown]
# Importing Model from Hugging Face Hub. For this example, we will go with google/flan-t5-xl which should be under 15 GB<br>

# %%
import numpy as np
from tqdm import tqdm
from torch.utils.data import DataLoader
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
import os
import torch as p
from transformers import DataCollatorForSeq2Seq

# %%
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-xl")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-xl")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# The model is approximately as 77 Million Parameter Model as showcased by the code in the cell below

# %%
pytorch_total_params = sum(p.numel() for p in model.parameters())
print("Total Parameters: ", pytorch_total_params)
# Out:
# Total Parameters:  2849757184

# %% [markdown]
# However, if we use PEFT methodology for tuning our model, we need not train all the parameters of the model. We can train a disparate lightweight module and then merge the weights of the module with the weights of the original model. <br><br>
# For our example, we will be using the (IA)<sup>3</sup> method for tuning the model.
# To learn more about this methodology in particular, please take a look at this paper: https://arxiv.org/abs/2205.05638
#
# The implementation of (IA)<sup>3</sup> is present as a part of the adapter-transformers package. It is an extension over the transformers package along with PEFT tuning methods. If your device does not recognise this package even after installation, just make sure to uninstall the package transformers and only keep adapter-transformers in your environment
#
# We will need to grab the (IA)<sup>3</sup> config and pass it as a parameter to the add_adapter function. The name of the adapter can be anything you like really.

# %%
from transformers.adapters import IA3Config

config = IA3Config()
model.add_adapter("ia3_adapter", config = config)

# %% [markdown]
# Now that we have added an adapter, it is important to denote which adapter it is that we want to train. model.train() proceeds to freeze the models weights so that we only train the disparate lightweight module

# %%
model.train_adapter("ia3_adapter")
model.train()
# Out:
# T5ForConditionalGeneration(
#   (shared_parameters): ModuleDict()
#   (shared): Embedding(32128, 2048)
#   (encoder): T5Stack(
#     (invertible_adapters): ModuleDict()
#     (embed_tokens): Embedding(32128, 2048)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict()
#               )
#               (k): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (v): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#               (prefix_tuning): PrefixTuningShim(
#                 (prefix_gates): ModuleDict()
#                 (pool): PrefixTuningPool(
#                   (prefix_tunings): ModuleDict()
#                 )
#               )
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict()
#             (adapter_fusion_layer): ModuleDict()
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(
#                 in_features=2048, out_features=5120, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (wo): Linear(
#                 in_features=5120, out_features=2048, bias=False
#                 (loras): ModuleDict()
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict()
#             (adapter_fusion_layer): ModuleDict()
#           )
#         )
#       )
#       (1-23): 23 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict()
#               )
#               (k): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (v): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#               (prefix_tuning): PrefixTuningShim(
#                 (prefix_gates): ModuleDict()
#                 (pool): PrefixTuningPool(
#                   (prefix_tunings): ModuleDict()
#                 )
#               )
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict()
#             (adapter_fusion_layer): ModuleDict()
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(
#                 in_features=2048, out_features=5120, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (wo): Linear(
#                 in_features=5120, out_features=2048, bias=False
#                 (loras): ModuleDict()
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict()
#             (adapter_fusion_layer): ModuleDict()
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (invertible_adapters): ModuleDict()
#     (embed_tokens): Embedding(32128, 2048)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict()
#               )
#               (k): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (v): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#               (prefix_tuning): PrefixTuningShim(
#                 (prefix_gates): ModuleDict()
#                 (pool): PrefixTuningPool(
#                   (prefix_tunings): ModuleDict()
#                 )
#               )
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict()
#             (adapter_fusion_layer): ModuleDict()
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict()
#               )
#               (k): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (v): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#               (prefix_tuning): PrefixTuningShim(
#                 (prefix_gates): ModuleDict()
#                 (pool): PrefixTuningPool(
#                   (prefix_tunings): ModuleDict()
#                 )
#               )
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict()
#             (adapter_fusion_layer): ModuleDict()
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(
#                 in_features=2048, out_features=5120, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (wo): Linear(
#                 in_features=5120, out_features=2048, bias=False
#                 (loras): ModuleDict()
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict()
#             (adapter_fusion_layer): ModuleDict()
#           )
#         )
#       )
#       (1-23): 23 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict()
#               )
#               (k): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (v): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#               (prefix_tuning): PrefixTuningShim(
#                 (prefix_gates): ModuleDict()
#                 (pool): PrefixTuningPool(
#                   (prefix_tunings): ModuleDict()
#                 )
#               )
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict()
#             (adapter_fusion_layer): ModuleDict()
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict()
#               )
#               (k): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (v): Linear(
#                 in_features=2048, out_features=2048, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#               (prefix_tuning): PrefixTuningShim(
#                 (prefix_gates): ModuleDict()
#                 (pool): PrefixTuningPool(
#                   (prefix_tunings): ModuleDict()
#                 )
#               )
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict()
#             (adapter_fusion_layer): ModuleDict()
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(
#                 in_features=2048, out_features=5120, bias=False
#                 (loras): ModuleDict(
#                   (ia3_adapter): LoRA()
#                 )
#               )
#               (wo): Linear(
#                 in_features=5120, out_features=2048, bias=False
#                 (loras): ModuleDict()
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict()
#             (adapter_fusion_layer): ModuleDict()
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=2048, out_features=32128, bias=False)
#   (prefix_tuning): PrefixTuningPool(
#     (prefix_tunings): ModuleDict()
#   )
# )

# %% [markdown]
# As you can see in the cell below, we check for the number of parameters which require their gradients to be computed. Lo and behold, we see that we only have to train 540k parameters which is a huge drop from around 3B parameters

# %%
pytorch_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Total Parameters: ", pytorch_total_params)
# Out:
# Total Parameters:  540672

# %% [markdown]
# Since we are going to be tuning the model using the huggingface Trainer, let us get our training data (stored in train.csv) into a "datasets" object. Yes, datasets is a package that is offered by hugging face for structuring/storing our data before training

# %%
from datasets import load_dataset

dataset = load_dataset('csv', data_files = { 
        "train": "train_data.csv"
        })
# Out:
# Downloading and preparing dataset csv/default to C:/Users/JkReddy/.cache/huggingface/datasets/csv/default-bbfcff9c7623a4c3/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to C:/Users/JkReddy/.cache/huggingface/datasets/csv/default-bbfcff9c7623a4c3/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset = dataset.remove_columns("Unnamed: 0")
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Instruction', 'Context', 'Question', 'Choices', 'Answer'],
#         num_rows: 33
#     })
# })

# %% [markdown]
# Before I explain the next teo cells, lets take one more look at how our data is structured
#
# **Instruction: Read the Context below and answer the Question based by picking from the Choices provided below<br>
# Context: The Clinician said, "His brother is homeless"<br>
# Question: "In the clinician\'s opinon, was the person themself homeless?""<br>
# Choices: Yes; No<br>
# Answer:** **<font color=red>No</font>**
#
# We have each of these sentences in separate columns as per best practices. But it would ideally be better if we could store the **bold** portion in one column and **<font color=red>No</font>** portion in another column before we pass everything to the Trainer.
#
# So, in the below two cells, we are gonna be dealing with concatenating the data and getting into all into two separate columns. Please feel free to perform whatever operations you may be comfortable with to get the data in the structure mentioned above. I will update this code later to simplify this portion. It definitely feels over engineered to me.

# %%
template = "Question: \"In the clinician's opinon, was the person themself homeless?\"\nChoices: Yes; No"
instruction = "Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices."

# %%
def add_template(examples):
    for i,ex in enumerate(examples['Context']):
        try:
#             print(ex)
#             print("h")
            examples['Context'][i] = instruction + "\nContext: " + ex + "\n" + template + "\nAnswer:"
            print(examples['Context'][i], end = "\n\n")
        except:   
            print("yikes")
            print(examples['Context'][i])
    return examples

dataset = dataset.map(add_template, batched = True)
dataset
# Out:
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Social History: Pt is homeless."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Social History: He is homeless, and stays in a shelter."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "He is homeless and currently staying with friends."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "The patient is currently homeless, staying with friends, moved from   to   in  , homosexual."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "previously from  , moved to the states after high school; lives in   and works as a social worker with the homeless denies tobacco or IVDU drinks ETOH occasionally   "
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "The patient was born in  ,  . Previously homeless, currently resides in   Manor."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, " Mr.   is homeless and lives at   House in   for now."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Social History: homeless;   quarts vodka/day;   ppd tobacco; no recent ivdu, but used cocaine and heroin in the past; smokes MJ"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "He is now homeless and was taking the train to   when he decided to have a 40oz beer."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Currently homeless, but formerly living with an uncle in  . Previous alcohol abuser, but sober for 2 years until today."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "The patient was supposed to be discharged on  .  However, it was discovered that Mr.   was homeless after his brother kicked him out of the house and he had no place to go."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Pt has been living on the street for 3-4 months."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, " MEDICATIONS:  Denies any current home medications."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, ""Has lost job at homeless shelter   EtOH abuse.""
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "In the past, patient stated to some providers he had a home in   and to others that he was homeless."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Social History: Unable to obtain, reports of homelessness."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "SOCIAL HISTORY:  The patient lives in a residence for elderly, homeless women.  The patient has a good resident contact,       who knows the patient very well."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Has been living with mother and caring for her. Will be moving back in with boyfriend soon.   hx of homelessness;"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "She has a history of homelessness"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Has been there since ' ?"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Social History: Lives alone with several cats, found in filthy apt full of feces."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Group home can be reached at  ."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, " Chief Complaint:  0 ft."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Physical Exam: VS: 97.5 149/82 57 20 99/3L (no home O2)"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "He has spent time in a homeless shelter x 1 month 3 months ago and was incarcerated last in  ."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "evicted yesterday."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "his brother was homeless"
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, " 5. Follow up:  Complicated social situation with tenuous housing; lives on street as well as with children.  Seen by SW while in house; offered etoh counseling/programs, but patient refused.  He will f/u with Dr.     in   clinic; on discharge, this appointment was set up."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "We discussed starting anticoagulation, but felt that it was unnecessary and potentially harmful in this patient with a CHADS-2 score of 1 (age), potential medical non-compliance (history of homelessness), and significant fall risk (history of multiple mechanical falls in recent weeks).  We started him on aspirin at a dose of 325 mg once daily."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Past Medical History: Alcohol Abuse Hypertension Pancreatitis Bulimia   Social History: - Tobacco: denies - Alcohol: history of abuse, currently in a detox program at   - Illicits: denies Currently homeless and living out of her car   "
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "Has previously stayed in multiple shelters."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, "SOCIAL HISTORY:  He is apparently homeless.  Alcohol - Unable to quantify."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
#
# Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.
# Context: The Clinician said, " Social work was closely involved throughout his hospital stay assisting with issues surrounding being homeless and for substance abuse."
# Question: "In the clinician's opinon, was the person themself homeless?"
# Choices: Yes; No
# Answer:
# DatasetDict({
#     train: Dataset({
#         features: ['Instruction', 'Context', 'Question', 'Choices', 'Answer'],
#         num_rows: 33
#     })
# })

# %% [markdown]
# In the next two cells, we are going to be tokenizing the "Data" (Context column) and "Label" (Answer column)

# %%
def preprocess_function(examples):
    inputs = [ex for ex in examples["Context"]]
    targets = [ex for ex in examples["Answer"]]
    print(inputs)
    model_inputs = tokenizer(
        inputs, text_target=targets, max_length= 512, truncation=True
    )
    return model_inputs

# %%
tokenized_datasets = dataset.map(
    preprocess_function,
    batched=True,
    remove_columns=dataset["train"].column_names,
)
# Out:
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# ['Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.\nContext: The Clinician said, "Social History: Pt is homeless."\nQuestion: "In the clinician\'s opinon, was the person themself homeless?"\nChoices: Yes; No\nAnswer:', 'Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.\nContext: The Clinician said, "Social History: He is homeless, and stays in a shelter."\nQuestion: "In the clinician\'s opinon, was the person themself homeless?"\nChoices: Yes; No\nAnswer:', 'Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.\nContext: The Clinician said, "He is homeless and currently staying with friends."\nQuestion: "In the clinician\'s opinon, was the person themself homeless?"\nChoices: Yes; No\nAnswer:', 'Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.\nContext: The Clinician said, "The patient is currently homeless, staying with friends, moved from   to   in  , homosexual."\nQuestion: "In the clinician\'s opinon, was the person themself homeless?"\nChoices: Yes; No\nAnswer:', 'Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.\nContext: The Clinician said, "previously from  , moved to the states after high school; lives in   and works as a social worker with the homeless denies tobacco or IVDU drinks ETOH occasionally   "\nQuestion: "In the clinician\'s opinon, was the person themself homeless?"\nChoices: Yes; No\nAnswer:', 'Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.\nContext: The Clinician said, "The patient was born in  ,  . Previously homeless, currently resides in   Manor."\nQuestion: "In the clinician\'s opinon, was the person themself homeless?"\nChoices: Yes; No\nAnswer:', 'Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.\nContext: The Clinician said, " Mr.   is homeless and lives at   House in   for now."\nQuestion: "In the clinician\'s opinon, was the person themself homeless?"\nChoices: Yes; No\nAnswer:', 'Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.\nContext: The Clinician said, "Social History: homeless;   quarts vodka/day;   ppd tobacco; no recent ivdu, but used cocaine and heroin in the past; smokes MJ"\nQuestion: "In the clinician\'s opinon, was the person themself homeless?"\nChoices: Yes; No\nAnswer:', 'Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.\nContext: The Clinician said, "He is now homeless and was taking the train to   when he decided to have a 40oz beer."\nQuestion: "In the clinician\'s opinon, was the person themself homeless?"\nChoices: Yes; No\nAnswer:', 'Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.\nContext: The Clinician said, "Currently homeless, but formerly living with an uncle in  . Previous alcohol abuser, but sober for 2 years until today."\nQuestion: "In the clinician\'s opinon, was the person themself homeless?"\nChoices: Yes; No\nAnswer:', 'Instruction: Read what the Clinician said in the Context below and answer the Question by choosing from the below provided Choices.\nContext: The Clinician said, "The patient was supposed to be discharged on  .  However, it was discovered that Mr.   was homeless after his brother kicked him out of the house and he had no place to go."\nQuestion: "In the clinician\'s opinon, was the person themself homeless?"\nChoices: Yes; No\nAnswer:', ...

# %% [markdown]
# Data Collators take care of padding the entities in our dataset and getting it ready for prime time. <br>
# Why do we need padding you ask? Please read this article for more details: https://medium.com/@canerkilinc/padding-for-nlp-7dd8598c916a

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %% [markdown]
# We use the Hugging Face Trainer to Train the Model. We are setting the arguments for training in the cell below. Please feel free to read more about best parameters for the model you are going to be training. It is always good to have warmup steps (1% of the total steps) as this will result in a better model. Weight decay can also be set to a moderate 0.05 to ensure that we are not overfitting. I will update this notebook later with a detailed explanation of each of these parameters. We are not gonna be using a GPU for this example. But if you do want to use your Nvidia GPU with CUDA cores, set no_cuda to False. Let us run the model for 15 epochs. The output directory of the trained model will be "tuned_model/flan-t5-small"

# %%
from transformers import Seq2SeqTrainingArguments
epochs = 5
args = Seq2SeqTrainingArguments(
   f"tuned_model/flan-t5-xl_demo", 
#     evaluation_strategy="epoch",
#     save_strategy = "epoch",
    learning_rate = 3e-3,
#     logging_steps = 1,
    per_device_train_batch_size = 1,
    per_device_eval_batch_size = 1,
    weight_decay=0.05,
    num_train_epochs= epochs,
    predict_with_generate=True,
#     load_best_model_at_end = True,
#     metric_for_best_model = "eval_loss",
    greater_is_better = False,
    logging_strategy = "epoch",
    no_cuda = True,
#     save_total_limit = 2,   
    warmup_steps = (len(dataset["train"]) * epochs)/10,
    max_steps = len(dataset["train"]) * epochs
#     fp16=True,
#     fp16_full_eval = True
)

# %% [markdown]
# Creating the Trainer object which takes in the model, arguments which we previously initialized, data, data collator and tokenizer

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=tokenized_datasets["train"],
#     eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
#     compute_metrics=compute_metrics,
#     callbacks=[early_stop],
)
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %% [markdown]
# Running the Trainer

# %%
trainer.train()
# Out:
# c:\program files\python38\lib\site-packages\transformers\optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 33
#   Num Epochs = 5
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
#   Gradient Accumulation steps = 1
#   Total optimization steps = 165
#   Number of trainable parameters = 540672
#     <div>
#
#       <progress value='165' max='165' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [165/165 13:46, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>33</td>
#       <td>0.288300</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.152500</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.108700</td>
#     </tr>
#     <tr>
#       <td>132</td>
#       <td>0.093800</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.044700</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=165, training_loss=0.13760994492155132, metrics={'train_runtime': 856.0706, 'train_samples_per_second': 0.193, 'train_steps_per_second': 0.193, 'total_flos': 247263392563200.0, 'train_loss': 0.13760994492155132, 'epoch': 5.0})

# %% [markdown]
# Let us now merge the weights of the adapter with the model (and I guess you could delete the adapter)

# %%
trainer.model.merge_adapter("ia3_adapter")

# %% [markdown]
# Saving the final model in the folder mentioned in the arguments above

# %%
trainer.save_model()
# Out:
# Saving model checkpoint to tuned_model/flan-t5-xl_demo
# Configuration saved in tuned_model/flan-t5-xl_demo\config.json
# Configuration saved in tuned_model/flan-t5-xl_demo\generation_config.json
# The model is bigger than the maximum size per checkpoint (10GB) and is going to be split in 2 checkpoint shards. You can find where each parameters has been saved in the index located at tuned_model/flan-t5-xl_demo\pytorch_model.bin.index.json.
# tokenizer config file saved in tuned_model/flan-t5-xl_demo\tokenizer_config.json
# Special tokens file saved in tuned_model/flan-t5-xl_demo\special_tokens_map.json

# %% [markdown]
# Quantization and Inferencing is done in the next notebook:<br>
# (Part 2)
